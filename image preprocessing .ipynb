# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
from scipy.ndimage import interpolation as inter

# %%
def correct_skew(image, delta=1, limit=5):
    def determine_score(arr, angle):
        data = inter.rotate(arr, angle, reshape=False, order=0)
        histogram = np.sum(data, axis=1)
        score = np.sum((histogram[1:] - histogram[:-1]) ** 2)
        return histogram, score

    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1] 

    scores = []
    angles = np.arange(-limit, limit + delta, delta)
    for angle in angles:
        histogram, score = determine_score(thresh, angle)
        scores.append(score)

    best_angle = angles[scores.index(max(scores))]

    (h, w) = image.shape[:2]
    center = (w // 2, h // 2)
    M = cv2.getRotationMatrix2D(center, best_angle, 1.0)
    rotated = cv2.warpAffine(image, M, (w, h), flags=cv2.INTER_CUBIC, \
              borderMode=cv2.BORDER_REPLICATE)

    return best_angle, rotated

# %%
#reading the original image using OpenCV
image = cv2.imread('Original.jpg')

# %%
#Converting the colored image to greyscale
angle, rotated = correct_skew(image)
print(angle)
cv2.imwrite('rotated.jpg', rotated)
gray = cv2.cvtColor(rotated,cv2.COLOR_BGR2GRAY)
thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]
# Out:
# C:\Users\praveena\AppData\Local\Temp\ipykernel_21472\3330985539.py:3: DeprecationWarning: Please import `rotate` from the `scipy.ndimage` namespace; the `scipy.ndimage.interpolation` namespace is deprecated and will be removed in SciPy 2.0.0.
#   data = inter.rotate(arr, angle, reshape=False, order=0)
# -4

# %%
# Remove horizontal lines
horizontal_kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (40,1))
remove_horizontal = cv2.morphologyEx(thresh, cv2.MORPH_OPEN, horizontal_kernel, iterations=2)
cnts = cv2.findContours(remove_horizontal, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
cnts = cnts[0] if len(cnts) == 2 else cnts[1]
for c in cnts:
    cv2.drawContours(rotated, [c], -1, (255,255,255), 5)

# %%
# Remove vertical lines
vertical_kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (1,40))
remove_vertical = cv2.morphologyEx(thresh, cv2.MORPH_OPEN, vertical_kernel, iterations=2)
cnts = cv2.findContours(remove_vertical, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
cnts = cnts[0] if len(cnts) == 2 else cnts[1]
for c in cnts:
    cv2.drawContours(rotated, [c], -1, (255,255,255), 5)

# %%
gray = cv2.cvtColor(rotated,cv2.COLOR_BGR2GRAY)

# %%
#applying median filter for Salt and pepper/impulse noise
filter1 = cv2.medianBlur(gray,5)

# %%
#applying gaussian blur to smoothen out the image edges
filter2 = cv2.GaussianBlur(filter1,(5,5),0)

# %%
#applying non-localized means for final Denoising of the image
dst = cv2.fastNlMeansDenoising(filter2,None,17,9,17)

# %%
#converting the image to binarized form using adaptive thresholding
th1 = cv2.adaptiveThreshold(dst,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY,11,2)

# %%
cv2.imwrite('ImagePreProcessingFinal.jpg', th1)
# Out:
# True

# %%
plt.imshow(th1)

# %%
import cv2
import os
import numpy as np
import imutils
import matplotlib.pyplot as plt

# %%
pip install imutils
# Out:
# Requirement already satisfied: imutils in c:\users\praveena\.android\new folder\envs\mlproj\lib\site-packages (0.5.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
image = cv2.imread("ImagePreProcessingFinal.jpg")
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
gray = cv2.GaussianBlur(gray, (7, 7), 0)

# %%
ret,thresh1 = cv2.threshold(gray ,127,255,cv2.THRESH_BINARY_INV)

# %%
dilate = cv2.dilate(thresh1, None, iterations=2)

# %%
cnts = cv2.findContours(dilate.copy(), cv2.RETR_EXTERNAL,
    cv2.CHAIN_APPROX_SIMPLE)
cnts = cnts[1] if imutils.is_cv2() else cnts[0]

# %%
sorted_ctrs = sorted(cnts, key=lambda ctr: cv2.boundingRect(ctr)[0] + cv2.boundingRect(ctr)[1] * image.shape[1] )

# %%
orig = image.copy()
i = 0
fig =plt.figure(figsize = (10,10))

directory = r'C:\Users\praveena\Downloads\Tamil-Epigraphs-data-creation-and-recognition-main\Tamil-Epigraphs-data-creation-and-recognition-main\project related data and model\sarana_test_images'

print(os.chdir(directory))
print(os.getcwd())
for cnt in sorted_ctrs:
#     print(cv2.contourArea(cnt))
    # Check the area of contour, if it is very small ignore it
    if(cv2.contourArea(cnt) < 200):
        continue
    
    # Filtered countours are detected
    x,y,w,h = cv2.boundingRect(cnt)
    
    # Taking ROI of the cotour
    roi = image[y:y+h, x:x+w]
    
    # Mark them on the image if you want
    cv2.rectangle(orig,(x,y),(x+w,y+h),(0,255,0),2)
    
    # Save your contours or characters
    print(cv2.imwrite(r"C:\Users\praveena\Downloads\Tamil-Epigraphs-data-creation-and-recognition-main\Tamil-Epigraphs-data-creation-and-recognition-main\project related data and model\sarana_test_images" + str(i) + ".png", roi))
    
    
    i = i + 1
# Out:
# None
# C:\Users\praveena\Downloads\Tamil-Epigraphs-data-creation-and-recognition-main\Tamil-Epigraphs-data-creation-and-recognition-main\project related data and model\sarana_test_images
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True

# %%
if orig is None:
    print("Error: Image not loaded correctly.")
else:

    plt.imshow(orig)


    plt.axis('off')

    plt.savefig("C:/Users/praveena\Downloads/Tamil-Epigraphs-data-creation-and-recognition-main (1)/Tamil-Epigraphs-data-creation-and-recognition-main/box.jpg", bbox_inches='tight', pad_inches=0)
    plt.close() 

    print("Image saved as 'box.jpg'.")
# Out:
# Image saved as 'box.jpg'.

# %%
cv2.imwrite("box.jpg",orig)
# Out:
# True

# %%
from tensorflow.keras.preprocessing import image
from keras.applications.vgg16 import VGG16
from keras.applications.vgg16 import preprocess_input
import numpy as np
from sklearn.cluster import KMeans
import os, shutil, glob, os.path
from PIL import Image as pil_image
image.LOAD_TRUNCATED_IMAGES = True

# %%
model = VGG16(weights='imagenet', include_top=False)

# %%
imdir = r'C:\Users\praveena\Downloads\Tamil-Epigraphs-data-creation-and-recognition-main\Tamil-Epigraphs-data-creation-and-recognition-main\project related data and model\sarana_test_images'
os.chdir(imdir)
targetdir = r'C:\Users\praveena\Downloads\Tamil-Epigraphs-data-creation-and-recognition-main\Tamil-Epigraphs-data-creation-and-recognition-main\project related data and model\images_categorised'
number_clusters = 28

# %%
# Loop over files and get features
filelist = glob.glob(os.path.join(imdir, '*.PNG'))
filelist.sort()
featurelist = []
labels = []
print(filelist)
# Out:
# ['C:\\Users\\praveena\\Downloads\\Tamil-Epigraphs-data-creation-and-recognition-main\\Tamil-Epigraphs-data-creation-and-recognition-main\\project related data and model\\sarana_test_images\\box.png', 'C:\\Users\\praveena\\Downloads\\Tamil-Epigraphs-data-creation-and-recognition-main\\Tamil-Epigraphs-data-creation-and-recognition-main\\project related data and model\\sarana_test_images\\sarana_test_images0.png', 'C:\\Users\\praveena\\Downloads\\Tamil-Epigraphs-data-creation-and-recognition-main\\Tamil-Epigraphs-data-creation-and-recognition-main\\project related data and model\\sarana_test_images\\sarana_test_images1.png', 'C:\\Users\\praveena\\Downloads\\Tamil-Epigraphs-data-creation-and-recognition-main\\Tamil-Epigraphs-data-creation-and-recognition-main\\project related data and model\\sarana_test_images\\sarana_test_images10.png', 'C:\\Users\\praveena\\Downloads\\Tamil-Epigraphs-data-creation-and-recognition-main\\Tamil-Epigraphs-data-creation-and-recognition-main\\project related data and model\\sarana_test_images\\sarana_test_images100.png', 'C:\\Users\\praveena\\Downloads\\Tamil-Epigraphs-data-creation-and-recognition-main\\Tamil-Epigraphs-data-creation-and-recognition-main\\project related data and model\\sarana_test_images\\sarana_test_images101.png', 'C:\\Users\\praveena\\Downloads\\Tamil-Epigraphs-data-creation-and-recognition-main\\Tamil-Epigraphs-data-creation-and-recognition-main\\project related data and model\\sarana_test_images\\sarana_test_images102.png', 'C:\\Users\\praveena\\Downloads\\Tamil-Epigraphs-data-creation-and-recognition-main\\Tamil-Epigraphs-data-creation-and-recognition-main\\project related data and model\\sarana_test_images\\sarana_test_images103.png', 'C:\\Users\\praveena\\Downloads\\Tamil-Epigraphs-data-creation-and-recognition-main\\Tamil-Epigraphs-data-creation-and-recognition-main\\project related data and model\\sarana_test_images\\sarana_test_images104.png', 'C:\\Users\\praveena\\Downloads\\Tamil-Epigraphs-data-creation-and-recognition-main\\Tamil-Epigraphs-data-creation-and-recognition-main\\project related data and model\\sarana_test_images\\sarana_test_images105.png', 'C:\\Users\\praveena\\Downloads\\Tamil-Epigraphs-data-creation-and-recognition-main\\Tamil-Epigraphs-data-creation-and-recognition-main\\project related data and model\\sarana_test_images\\sarana_test_images106.png', 'C:\\Users\\praveena\\Downloads\\Tamil-Epigraphs-data-creation-and-recognition-main\\Tamil-Epigraphs-data-creation-and-recognition-main\\project related data and model\\sarana_test_images\\sarana_test_images107.png', 'C:\\Users\\praveena\\Downloads\\Tamil-Epigraphs-data-creation-and-recognition-main\\Tamil-Epigraphs-data-creation-and-recognition-main\\project related data and model\\sarana_test_images\\sarana_test_images108.png', 'C:\\Users\\praveena\\Downloads\\Tamil-Epigraphs-data-creation-and-recognition-main\\Tamil-Epigraphs-data-creation-and-recognition-main\\project related data and model\\sarana_test_images\\sarana_test_images109.png', 'C:\\Users\\praveena\\Downloads\\Tamil-Epigraphs-data-creation-and-recognition-main\\Tamil-Epigraphs-data-creation-and-recognition-main\\project related data and model\\sarana_test_images\\sarana_test_images11.png', 'C:\\Users\\praveena\\Downloads\\Tamil-Epigraphs-data-creation-and-recognition-main\\Tamil-Epigraphs-data-creation-and-recognition-main\\project related data and model\\sarana_test_images\\sarana_test_images110.png', 'C:\\Users\\praveena\\Downloads\\Tamil-Epigraphs-data-creation-and-recognition-main\\Tamil-Epigraphs-data-creation-and-recognition-main\\project related data and model\\sarana_test_images\\sarana_test_images111.png', 'C:\\Users\\praveena\\Downloads\\Tamil-Epigraphs-data-creation-and-recognition-main\\Tamil-Epigraphs-data-creation-and-recognition-main\\project related data and model\\sarana_test_images\\sarana_test_images112.png', 'C:\\Users\\praveena\\Downloads\\Tamil-Epigraphs-data-creation-and-recognition-main\\Tamil-Epigraphs-data-creation-an ...

# %%
for i, imagepath in enumerate(filelist):
    print("Status: %s / %s" %(i+1, len(filelist)), end="\r")
    img = image.load_img(imagepath, target_size=(224, 224))
    imagepath = imagepath.replace("\\", "/")
    print(imagepath)    
    start = (imagepath[51:]).index("/")
    end = (imagepath[51+1+start:]).index("/")
    labels.append(imagepath[52+start:52+start+end])  
    
    img_data = image.img_to_array(img)
    img_data = np.expand_dims(img_data, axis=0)
    img_data = preprocess_input(img_data)
    features = np.array(model.predict(img_data))
    featurelist.append(features.flatten())

print("Labels - ", labels)
# Out:
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/box.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 746ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images0.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 514ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images1.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images10.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images100.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 403ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images101.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images102.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 415ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images103.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images104.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images105.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images106.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images107.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images108.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images109.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images11.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images110.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images111.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images112.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 421ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images113.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 394ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images114.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images115.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 471ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images116.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images117.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images118.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images119.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images12.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 490ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images120.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 428ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images121.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images122.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images123.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images124.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 481ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images125.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 430ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images126.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images127.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 430ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images128.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 415ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images129.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 403ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images13.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images130.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images131.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images132.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images133.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images134.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images135.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images136.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images137.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images138.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images139.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images14.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images140.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images141.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images142.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images143.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images144.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images145.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images146.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images147.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images148.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images149.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images15.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images150.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images151.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 475ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images152.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images153.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images154.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images155.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images156.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 356ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images157.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 348ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images158.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images159.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images16.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images160.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images161.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images162.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 362ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images163.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images164.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 407ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images165.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images166.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images167.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images168.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images169.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 348ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images17.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images170.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images171.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 342ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images172.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images173.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images18.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images19.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images2.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images20.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 470ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images21.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images22.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images23.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images24.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images25.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images26.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images27.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images28.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 386ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images29.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images3.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images30.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images31.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images32.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images33.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 384ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images34.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images35.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images36.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images37.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 432ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images38.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images39.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images4.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images40.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images41.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 307ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images42.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 468ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images43.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 446ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images44.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images45.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images46.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images47.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images48.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images49.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images5.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 412ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images50.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 389ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images51.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images52.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images53.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images54.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images55.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images56.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images57.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images58.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images59.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 436ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images6.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images60.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 394ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images61.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 388ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images62.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images63.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images64.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 356ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images65.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images66.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images67.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images68.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images69.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images7.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 360ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images70.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images71.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images72.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 508ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images73.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 436ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images74.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 475ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images75.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images76.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 437ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images77.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images78.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images79.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images8.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 404ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images80.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 484ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images81.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images82.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images83.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 430ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images84.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 392ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images85.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 381ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images86.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images87.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 392ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images88.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images89.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images9.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 412ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images90.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images91.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images92.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 379ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images93.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 350ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images94.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images95.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images96.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 388ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images97.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 350ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images98.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step
# C:/Users/praveena/Downloads/Tamil-Epigraphs-data-creation-and-recognition-main/Tamil-Epigraphs-data-creation-and-recognition-main/project related data and model/sarana_test_images/sarana_test_images99.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step
# Labels -  ['Tamil-Epigraphs-data-creation-and-recognition-main', 'Tamil-Epigraphs-data-creation-and-recognition-main', 'Tamil-Epigraphs-data-creation-and-recognition-main', 'Tamil-Epigraphs-data-creation-and-recognition-main', 'Tamil-Epigraphs-data-creation-and-recognition-main', 'Tamil-Epigraphs-data-creation-and-recognition-main', 'Tamil-Epigraphs-data-creation-and-recognition-main', 'Tamil-Epigraphs-data-creation-and-recognition-main', 'Tamil-Epigraphs-data-creation-and-recognition-main', 'Tamil-Epigraphs-data-creation-and-recognition-main', 'Tamil-Epigraphs-data-creation-and-recognition-main', 'Tamil-Epigraphs-data-creation-and-recognition-main', 'Tamil-Epigraphs-data-creation-and-recognition-main', 'Tamil-Epigraphs-data-creation-and-recognition-main', 'Tamil-Epigraphs-data-creation-and-recognition-main', 'Tamil-Epigraphs-data-creation-and-recognition-main', 'Tamil-Epigraphs-data-creation-and-recognition-main', 'Tamil-Epigraphs-data-creation-and-recognition-main', 'Tamil-Epigraphs-data-creation-and-recognition-main', 'Tamil-Epigraphs-data-creation-and-recognition-main', 'Tamil-Epigraphs-data-creation-and-recognition-main', 'Tamil-Epigraphs-data-creation-and-recognition-main', 'Tamil-Epigraphs-data-creation-and-recognition-main', 'Tamil-Epigraphs-data-creation-and-recognition-main', 'Tamil-Epigraphs-data-creation-and-recognition-main', 'Tamil-Epigraphs-data-creation-and-recognition-main', 'Tamil-Epigraphs-data-creation-and-recognition-main', 'Tamil-Epigraphs-data-creation-and-recognition-main', 'Tamil-Epigraphs-data-creation-and-recognition-main', 'Tamil-Epigraphs-data-creation-and-recognition-main', 'Tamil-Epigraphs-data-creation-and-recognition-main', 'Tamil-Epigraphs-data-creation-and-recognition-main', 'Tamil-Epigraphs-data-creation-and-recognition-main', 'Tamil-Epigraphs-data-creation-and-recognition-main', 'Tamil-Epigraphs-data-creation-and-recognition-main', 'Tamil-Epigraphs-data-creation-and-recognition-main', 'Tamil-Epigraphs-data-creation-and-recognition-main', 'Tamil-Epigraphs-data-creation-and-recognition-main', 'Tamil-Epigraphs-data-creation-and-recognition-main', 'Tamil-Epigraphs-data-creation-and-recognition-main', 'Tamil-Epigraphs-data-creation-and-recognition-main', 'Tamil-Epigraphs-data-creation-and-recognition-main', 'Tamil-Epigraphs-data-creation-and-recognition-main', 'Tamil-Epigraphs-data-creation-and-recognition-main', 'Tamil-Epigraphs-data-creation-and-recognition-main', 'Tamil-Epigraphs-data-creation-and-recognition-main', 'Tamil-Epigraphs-data-creation-and-recognition-main', 'Tamil-Epigraphs-data-creation-and-recognition-main', 'Tamil-Epigraphs-data-creation-and-recognition-main', 'Tamil-Epigraphs-data-creation-and-recognition-main', 'Tamil-Epigraphs-data-creation-and-recognition-main', 'Tamil-Epigraphs-data-creation-and-recognition-main', 'Tamil-Epigraphs-data-creation-and-recognition-main', 'Tamil-Epigraphs-data-creation-and-recognition-main', 'Tamil-Epigraphs-data-creation-and-recognition-main', 'Tamil-Epigraphs-data-creation-and-recognition-main', 'Tamil-Epigraphs-data-creation-and-recognition-main', 'Tamil-Epigraphs-data-creation-and-recognition-main', 'Tamil-Epigraphs-data-creation-and-recognition-main', 'Tamil-Epigraphs-data-creation-and-recognition-main', 'Tamil-Epigraphs-data-creation-and-recognition-main', 'Tamil-Epigraphs-data-creation-and-recognition-main', 'Tamil-Epigraphs-data-creation-and-recognition-main', 'Tamil-Epigraphs-data-creation-and-recognition-main', 'Tamil-Epigraphs-data-creation-and-recognition-main', 'Tamil-Epigraphs-data-creation-and-recognition-main', 'Tamil-Epigraphs-data-creation-and-recognition-main', 'Tamil-Epigraphs-data-creation-and-recognition-main', 'Tamil-Epigraphs-data-creation-and-recognition-main', 'Tamil-Epigraphs-data-creation-and-recognition-main', 'Tamil-Epigraphs-data-creation-and-recognition-main', 'Tamil-Epigraphs-data-creation-and-recognition-main', 'Tamil-Epigraphs-data-creation-and-recognition-main', 'Tamil-Epigraphs-data-creation-and-recognition- ...

# %%
# Clustering
kmeans = KMeans(n_clusters=number_clusters, random_state=0).fit(np.array(featurelist))

# %%
try:
    os.makedirs(targetdir)
except OSError:
    pass

# %%
print("\n")
for i, m in enumerate(kmeans.labels_):
    try:
        os.makedirs(targetdir+'\\'+str(m))
        #print(m)
    except OSError:
        pass
    print("Copy: %s / %s" %(i+1, len(kmeans.labels_)), end="\r")
    shutil.copy(filelist[i], targetdir +'/'+ str(m) + "/" + str(i) + ".jpg")
# Out:
# Copy: 175 / 175
